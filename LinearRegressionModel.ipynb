# %% [markdown]
# # Linear Regression Model:
# ### Predicting the number of veteran suicides in 2025 and beyond.

# %%
#importing modules

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Defining variables for train and test set

# %%
dataset = pd.read_csv('averages.csv')
X = dataset[['year']]
y = dataset['average veteran suicides']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAE: 2.39
# MSE: 5.97
# RMSE: 2.44

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('Year')
plt.ylabel('Average # of Veteran Suicides')
plt.title('Linear Regression Model')
plt.legend()
plt.show()

# %% [markdown]
# #### Plotting all the actual points against the prediction line.

# %%
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('Year')
plt.ylabel('Average # of Veteran Suicides')
plt.title('Linear Regression Model: Actual vs Predicted Veteran Suicides')
plt.legend()
plt.show()

# %% [markdown]
# #### Predicting the numbers of veteran suicides in the years 2024, 2025, 2026, and 2027.

# %%
X_new = np.array([[2024], [2025], [2026], [2027]])
y_pred = model.predict(X_new)

prediction = pd.DataFrame({'Predicted': y_pred})
print(prediction)
# Out:
#     Predicted
# 0  177.350462
# 1  179.656615
# 2  181.962769
# 3  184.268923
# c:\Users\lucim\Capstone Project Files\Capstone-Project-MCDANIEL\Capstone-Project-MCDANIEL\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Plotting those predictions.

# %%
plt.plot(X_new, y_pred, color='green', label='Predicted')
plt.xlabel('Year')
plt.ylabel('Average # of Veteran Suicides')
plt.title('Linear Regression Model Showing Predictions of Veteran Suicides')
plt.legend()
plt.show()

# %% [markdown]
# #### Running the model on the rates.csv dataset.

# %%
data = pd.read_csv('rates.csv')
X1 = data[['year']]
y1 = data['rates of veteran suicides']

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = model1.predict(X1_test)

# %%
mae = mean_absolute_error(y1_test, y1_pred)
mse = mean_squared_error(y1_test, y1_pred)
rmse = np.sqrt(mse)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAE: 0.41
# MSE: 0.20
# RMSE: 0.45

# %%
plt.scatter(X1_test, y1_test, color='blue', label='Actual')
plt.plot(X1_test, y1_pred, color='red', label='Predicted')
plt.xlabel('Year')
plt.ylabel('Average Rates of Veteran Suicides')
plt.title('Linear Regression Model on Rates of Veteran Suicides')
plt.legend()
plt.show()

# %%
y1_pred = model1.predict(X_new)

plt.plot(X_new, y1_pred, color='purple', label='Predicted')
plt.xlabel('Year')
plt.ylabel('Average Rates of Veteran Suicides')
plt.title('Prediction on Rates of Veteran Suicides')

plt.show()
# Out:
# c:\Users\lucim\Capstone Project Files\Capstone-Project-MCDANIEL\Capstone-Project-MCDANIEL\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
